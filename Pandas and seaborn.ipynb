# %%
import pandas as pd

# %%
# import our dataset
pokemon_df = pd.read_csv('./pokemon.csv')
(pokemon_df)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon_df[pokemon_df['Name']=='Bulbasaur']
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
#
#    Speed  Generation  Legendary
# 0     45           1      False

# %%
pokemon_df[pokemon_df['Legendary']== True]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# ..   ...                  ...       ...       ...    ...  ...     ...
# 795  719              Diancie      Rock     Fairy    600   50     100
# 796  719  DiancieMega Diancie      Rock     Fairy    700   50     160
# 797  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 798  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 799  721            Volcanion      Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# ...

# %%
pokemon_df[pokemon_df['Type 1']=='Electric']
# Out:
#        #                      Name    Type 1  Type 2  Total  HP  Attack  \
# 30    25                   Pikachu  Electric     NaN    320  35      55
# 31    26                    Raichu  Electric     NaN    485  60      90
# 88    81                 Magnemite  Electric   Steel    325  25      35
# 89    82                  Magneton  Electric   Steel    465  50      60
# 108  100                   Voltorb  Electric     NaN    330  40      30
# 109  101                 Electrode  Electric     NaN    480  60      50
# 134  125                Electabuzz  Electric     NaN    490  65      83
# 146  135                   Jolteon  Electric     NaN    525  65      65
# 157  145                    Zapdos  Electric  Flying    580  90      90
# 186  172                     Pichu  Electric     NaN    205  20      40
# 193  179                    Mareep  Electric     NaN    280  55      40
# 194  180                   Flaaffy  Electric     NaN    365  70      55
# ...

# %%
pokemon_df[(pokemon_df['Defense'] > 100) & (pokemon_df['Sp. Def'] > 100)]
# Out:
#        #                     Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3    VenusaurMega Venusaur     Grass    Poison    625   80     100
# 12     9  BlastoiseMega Blastoise     Water       NaN    630   79     103
# 141  130    GyaradosMega Gyarados     Water      Dark    640   95     155
# 196  181    AmpharosMega Ampharos  Electric    Dragon    610   90      95
# 212  197                  Umbreon      Dark       NaN    525   95      65
# 230  213                  Shuckle       Bug      Rock    505   20      10
# 232  214  HeracrossMega Heracross       Bug  Fighting    600   80     185
# 264  245                  Suicune     Water       NaN    580  100      75
# 268  248  TyranitarMega Tyranitar      Rock      Dark    700  100     164
# 269  249                    Lugia   Psychic    Flying    680  106      90
# 283  260    SwampertMega Swampert     Water    Ground    635  100     150
# 327  302      SableyeMega Sableye      Dark     Ghost    480   50      85
# ...

# %%
pokemon_df.mean(numeric_only=True)
# Out:
# #             362.81375
# Total         435.10250
# HP             69.25875
# Attack         79.00125
# Defense        73.84250
# Sp. Atk        72.82000
# Sp. Def        71.90250
# Speed          68.27750
# Generation      3.32375
# Legendary       0.08125
# dtype: float64

# %%
pokemon_df['Attack'].mean()
# Out:
# np.float64(79.00125)

# %%
pokemon_df.describe().astype(int)
# Out:
#          #  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# count  800    800  800     800      800      800      800    800         800
# mean   362    435   69      79       73       72       71     68           3
# std    208    119   25      32       31       32       27     29           1
# min      1    180    1       5        5       10       20      5           1
# 25%    184    330   50      55       50       49       50     45           2
# 50%    364    450   65      75       70       65       70     65           3
# 75%    539    515   80     100       90       95       90     90           5
# max    721    780  255     190      230      194      230    180           6

# %%
pokemon_df['Attack'].describe().astype(int)
# Out:
# count    800
# mean      79
# std       32
# min        5
# 25%       55
# 50%       75
# 75%      100
# max      190
# Name: Attack, dtype: int64

# %%
pokemon_df[pokemon_df['Type 1']=='Fighting'].describe().astype(int)
# Out:
#          #  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# count   27     27   27      27       27       27       27     27          27
# mean   363    416   69      96       65       53       64     66           3
# std    218    102   25      28       18       28       22     26           1
# min     56    210   30      35       30       20       30     25           1
# 25%    171    326   50      80       54       35       49     45           1
# 50%    308    455   70     100       70       40       63     60           3
# 75%    536    497   79     120       79       62       75     86           5
# max    701    625  144     145       95      140      110    118           6

# %%
pokemon_df[pokemon_df['Legendary']== True]['Attack'].describe().astype(int)
# Out:
# count     65
# mean     116
# std       30
# min       50
# 25%      100
# 50%      110
# 75%      131
# max      190
# Name: Attack, dtype: int64

# %%
pokemon_df[pokemon_df['Legendary']== False]['Attack'].describe().astype(int)
# Out:
# count    735
# mean      75
# std       30
# min        5
# 25%       54
# 50%       72
# 75%       95
# max      185
# Name: Attack, dtype: int64

# %% [markdown]
# Python data visualization libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='Type 1', data=pokemon_df)
# Out:
# <Axes: xlabel='Type 1', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='Type 2', data=pokemon_df)
# Out:
# <Axes: xlabel='Type 2', ylabel='count'>

# %%
sns.displot(pokemon_df.Attack)

# %%
sns.displot(pokemon_df.Attack, kde=True)

# %%
sns.boxplot(x='Attack',data=pokemon_df)
# Out:
# <Axes: xlabel='Attack'>

# %%
plt.figure(figsize=(8,8))
sns.boxplot(data=pokemon_df)
# Out:
# <Axes: >

# %%
pokemon_stats = pokemon_df.drop(['Type 1', 'Type 2', '#', 'Legendary', 'Name', 'Total', 'Generation'], axis=1)

# %%
plt.figure(figsize=(8,8))
sns.boxplot(data=pokemon_stats)
# Out:
# <Axes: >

# %%
pokemon_df[pokemon_df['HP'] > 225]
# Out:
#        #     Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 121  113  Chansey  Normal    NaN    450  250       5        5       35
# 261  242  Blissey  Normal    NaN    540  255      10       10       75
#
#      Sp. Def  Speed  Generation  Legendary
# 121      105     50           1      False
# 261      135     55           2      False

# %%
pokemon_df[pokemon_df['HP'] < 10]
# Out:
#        #      Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 316  292  Shedinja    Bug  Ghost    236   1      90       45       30
#
#      Sp. Def  Speed  Generation  Legendary
# 316       30     40           3      False

# %%
pokemon_df[pokemon_df['Defense'] > 200]
# Out:
#        #                 Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 224  208  SteelixMega Steelix  Steel  Ground    610  75     125      230
# 230  213              Shuckle    Bug    Rock    505  20      10      230
# 333  306    AggronMega Aggron  Steel     NaN    630  70     140      230
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 224       55       95     30           2      False
# 230       10      230      5           2      False
# 333       60       80     50           3      False

# %%
pokemon_df[pokemon_df['Sp. Def'] > 200]
# Out:
#        #     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213  Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary
# 230      5           2      False
