# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
num = np.random.randn(150)

# %%
sns.distplot(num) #displot(histogram and kde)
# Out:
# C:\Users\GRACE\AppData\Local\Temp\ipykernel_16136\702644673.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(num)
# <Axes: ylabel='Density'>

# %%
sns.distplot(num, color='red')
# Out:
# C:\Users\GRACE\AppData\Local\Temp\ipykernel_16136\3599940637.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(num, color='red')
# <Axes: ylabel='Density'>

# %%
label_dist = pd.Series(num, name="variable x")

# %%
sns.distplot(label_dist)
# Out:
# C:\Users\GRACE\AppData\Local\Temp\ipykernel_16136\2491584116.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(label_dist)
# <Axes: xlabel='variable x', ylabel='Density'>

# %%
sns.distplot(label_dist, vertical=True)
# Out:
# C:\Users\GRACE\AppData\Local\Temp\ipykernel_16136\2617052109.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(label_dist, vertical=True)
# <Axes: xlabel='Density', ylabel='variable x'>

# %%
sns.distplot(label_dist, vertical=True, color='red')
# Out:
# C:\Users\GRACE\AppData\Local\Temp\ipykernel_16136\3734782787.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(label_dist, vertical=True, color='red')
# <Axes: xlabel='Density', ylabel='variable x'>

# %%
sns.distplot(label_dist, hist=False)
# Out:
# C:\Users\GRACE\AppData\Local\Temp\ipykernel_16136\2320608985.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(label_dist, hist=False)
# <Axes: xlabel='variable x', ylabel='Density'>

# %%
sns.distplot(label_dist, rug=True, hist=False)
# Out:
# C:\Users\GRACE\AppData\Local\Temp\ipykernel_16136\1501159344.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(label_dist, rug=True, hist=False)
# <Axes: xlabel='variable x', ylabel='Density'>

# %%
sns.distplot(label_dist, rug=True,hist=False, color='green')
# Out:
# C:\Users\GRACE\AppData\Local\Temp\ipykernel_16136\484260683.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(label_dist, rug=True,hist=False, color='green')
# <Axes: xlabel='variable x', ylabel='Density'>
